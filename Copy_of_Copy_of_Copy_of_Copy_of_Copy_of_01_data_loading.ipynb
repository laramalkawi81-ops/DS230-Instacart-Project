# %% [markdown]
# <a href="https://colab.research.google.com/github/laramalkawi81-ops/DS230-Instacart-Project/blob/main/Copy_of_Copy_of_Copy_of_Copy_of_Copy_of_01_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading and Initial Inspection
#
# In this notebook, we load the Instacart dataset files and perform an initial inspection
# to understand the structure and basic statistics of the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks', 'DS230_Final_Project', 'instacart_data']

# %%
os.listdir('/content/drive/MyDrive/instacart_data')
# Out:
# ['instacart_data']

# %%
os.listdir('/content/drive/MyDrive/instacart_data')
# Out:
# ['instacart_data']

# %%
import pandas as pd
import numpy as np
