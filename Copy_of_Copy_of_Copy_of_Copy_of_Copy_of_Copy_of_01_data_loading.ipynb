# %% [markdown]
# <a href="https://colab.research.google.com/github/laramalkawi81-ops/DS230-Instacart-Project/blob/main/Copy_of_Copy_of_Copy_of_Copy_of_Copy_of_Copy_of_01_data_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading and Initial Inspection
#
# In this notebook, we load the Instacart dataset files and perform an initial inspection
# to understand the structure and basic statistics of the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks', 'DS230_Final_Project', 'instacart_data']

# %%
os.listdir('/content/drive/MyDrive/instacart_data')
# Out:
# ['instacart_data']

# %%
os.listdir('/content/drive/MyDrive/instacart_data/instacart_data')
# Out:
# ['departments.csv',
#  'aisles.csv',
#  'order_products__prior.csv',
#  'order_products__train.csv',
#  'products.csv',
#  'orders.csv']

# %%
import pandas as pd
import numpy as np
import os

DATA_PATH = '/content/drive/MyDrive/instacart_data/instacart_data'

orders = pd.read_csv(os.path.join(DATA_PATH, 'orders.csv'))
products = pd.read_csv(os.path.join(DATA_PATH, 'products.csv'))
aisles = pd.read_csv(os.path.join(DATA_PATH, 'order_products__train.csv'))
departments = pd.read_csv(os.path.join(DATA_PATH, 'order_products__prior.csv'))
order_products_prior = pd.read_csv(os.path.join(DATA_PATH, 'aisles.csv'))
order_products_train = pd.read_csv(os.path.join(DATA_PATH, 'departments.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4037687446.py in <cell line: 0>()
#       5 DATA_PATH = '/content/drive/MyDrive/instacart_data/instacart_data'
#       6
# ----> 7 orders = pd.read_csv(os.path.join(DATA_PATH, 'orders.csv'))
#       8 products = pd.read_csv(os.path.join(DATA_PATH, 'products.csv'))
#       9 aisles = pd.read_csv(os.path.join(DATA_PATH, 'order_products__train.csv'))
#
# ...

# %%
import pandas as pd
import numpy as np
