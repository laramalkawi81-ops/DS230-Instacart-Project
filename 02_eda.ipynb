# %% [markdown]
# <a href="https://colab.research.google.com/github/laramalkawi81-ops/DS230-Instacart-Project/blob/main/02_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Data Anlysis & Preprocessing
#
# This notebook performs exploratory data analy

# %%
#Exploratory Data Anlysis & Preprocessing
This notebook performs exploratory data analysis and preprocessing on the Instacart dataset.
The goal is to understand the data, detcet issue, and prepare features for modeling.


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns' , None)

## Load Dataset Files
We load all Instacart dataset files using pandas.

orders = pd.read_csv("order.csv")
order_products = pd.read_csv("order_products__prior.csv")
products = pd.read_csv("products.csv")
aisles = pd.read_csv("aisles.csv")
departments = pd.read_csv("departments.csv")

##Dataset Overview
We inspect the structure and basic statistics of each dataset.

orders.info()
orders.head()

## Missing Values Analysis
We analyze missing values values in the datasets.

orders.isnull().sum()

products.isnull().sum

##Distribution of Orders per User
This plot shows how many orders each user has placed.

orders.groupby("user_id")["order_number"].max().
plt.xlabel("Number of Orders")
plt.ylable("Number of Users")
plt.title("Orders per User")
plt.show()
